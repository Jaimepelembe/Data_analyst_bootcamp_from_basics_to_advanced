# %% [markdown]
# # Data Preprocessing
#
# Data preprocessing involves cleaning and transforming raw data(dados brutos) into a usable format for accurate and reliable analysis.

# %% [markdown]
# ## 1. What is Data Processing?
#
# Is the process of converting data into information and vice-versa.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### A: Processing Data vs Processed Data
# Processing Data reflects the ongoing activities to improve data quality;
#
# Processed data represents the outcome of those activities.

# %% [markdown]
# ## 2. Stages of Data Processing Process
#
# There are six fundamental stages of data processing process:

# %% [markdown]
# ### 2.1 Collection
#
# The process begins with the collection of raw data from various sources.
# It could include surveys, sensors, databases, or any other means of gathering relevant information.

# %% [markdown]
# ### 2.2 Preparation
#
# Focuses on organizing, data cleaning, and formatting raw data. Irrelevant information is filtered out, errors are corrected, and the data is structured in a way that facilitates efficient analysis during subsequent stages of processing.

# %% [markdown]
# ### 2.3 Input
#
# The prepared data is entered into a computer system. This can be achieved through manual entry or automated methods, depending on the nature of the data and the systems in place.

# %% [markdown]
# ### 2.4 Data Processing
#
# The core of data processing involves manipulating and analyzing the prepared data. Operations such as sorting, summarizing, calculating, and aggregating are performed to extract meaningful insights and patterns.

# %% [markdown]
# ### 2.5 Data Output
#
# The results of data processing are presented in a comprehensible format during the data output stage. This could include reports, charts, graphs, or other visual representations that facilitate understanding and decision-making based on the analyzed data.

# %% [markdown]
# ### 2.6 Data Storage
#
# The final stage entails storing the processed data for future reference and analysis. This is crucial for maintaining a historical record, enabling efficient retrieval, and supporting ongoing or future data-related initiatives.

# %% [markdown]
# ## 3. Types of Data Processing
# There are 7 types of Data Processing. The principal are manual, mechanical and electronic.

# %% [markdown]
# ### 3.1 Manual
#
# Data is processed by humans without the use of machines or electronic devices. It involves tasks such as manual calculations, sorting, and recording, making it a time-consuming process.

# %% [markdown]
# ### 3.2 Mechanical
#
# Utilizes mechanical devices, such as punch cards or mechanical calculators, to process data. While more efficient than manual processing, it lacks the speed and capabilities of electronic methods.

# %% [markdown]
# ### 3.3 Electronic
#
# Electronic Data Processing involves the use of computers to process and analyze data. Enhances speed and accuracy compared to manual and mechanical methods

# %% [markdown]
# ### 3.4 Batch
#
# Involves grouping data into batches and processing them together at a scheduled time. It is suitable for non-time-sensitive tasks and is efficient for large-scale data processing.

# %% [markdown]
# ### 3.5 Real-time
#
# Real-time processing deals with data immediately as it is generated. It is crucial for time-sensitive applications, providing instant responses and updates, often seen in applications like financial transactions and monitoring systems.

# %% [markdown]
# ### 3.6 Online
#
# Involves processing data directly while it is being collected. It is interactive and supports concurrent transactions, making it suitable for applications that require simultaneous user interaction and data updates.

# %% [markdown]
# ### 3.7 Automatic
#
# Refers to the use of computers and software to automate data processing tasks. It encompasses various methods, including batch processing and real-time processing, to efficiently handle large volumes of data with minimal human intervention.

# %% [markdown]
# ### Examples of Data Processing
#
# Stock exchanges process a massive volume of data during trades;
#
# In manufacturing, data processing is used for quality control;
#
# Smart home devices process data from sensors and user inputs to perform tasks like adjusting thermostats, controlling lights, etc;
#
# Electronic Health Records store and process patient data in healthcare settings. This includes medical history, test results, and treatment plans, facilitating efficient and accurate healthcare delivery.

# %% [markdown]
# ### Advantages of Data processing
# Highly efficient;
#
# Time-saving;
#
# High speed;
#
# Reduces errors.

# %% [markdown]
# ### Disadvantages of Data processing
# Large power consumption;
#
# Occupies large memory;
#
# The cost of installation is high;
#
# Wastage of memory.

# %% [markdown]
# ### The Future of Data Processing
#
# The future of data processing lies in the seamless integration of advanced analytics techniques, machine learning, and artificial intelligence to derive actionable insights and support informed decision-making.

# %% [markdown]
# ## 4. From Processing Data to Performing Analytics
#
# Analytics involves the application of statistical and mathematical techniques to uncover patterns, trends, and relationships within the data. Whether using descriptive, diagnostic, predictive, or prescriptive analytics, organizations can extract valuable information to make informed decisions, optimize processes, and gain a deeper understanding of their operations.
