# %% [markdown]
# File path

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\jaimi\Documents\Programacao\Data_analyst_bootcamp_from_basics_to_advanced\S3_Complete_Python\9_file_path

# %% [markdown]
# Create a new directory

# %%
newDirectory="package"
os.mkdir(newDirectory)
print(f"Directory {newDirectory} was created")
# Out:
# Directory package was created

# %% [markdown]
# List all files and directories

# %%
items=os.listdir(".") # dot(.) means the current directory
print(items)
# Out:
# ['filePath.ipynb', 'package']

# %%
items2=os.listdir("../8_file_operation") 
print(items2)
# Out:
# ['destination.txt', 'example.bin', 'example.txt', 'fileOperation.ipynb']

# %% [markdown]
# Joining Paths

# %%
dirName="folder"
fileName="file.txt"
relativePath=os.path.join(dirName,fileName)
print(relativePath)
# Out:
# folder\file.txt

# %%
absolutePath=os.path.join(os.getcwd(),dirName,fileName)
print(absolutePath)
# Out:
# c:\Users\jaimi\Documents\Programacao\Data_analyst_bootcamp_from_basics_to_advanced\S3_Complete_Python\9_file_path\folder\file.txt

# %%
#Verifying if a path exists or not

path="example1.txt"
path2="package"
path3="filePath.ipynb"

def verifyPath(path):
    if os.path.exists(path):
        print(f"The path {path} exists")
    else:
        print(f"The path {path} does not exists")


verifyPath(path)
verifyPath(path2)
verifyPath(path3)
# Out:
# The path example1.txt does not exists
# The path package exists
# The path filePath.ipynb exists

# %% [markdown]
# Checking if a Path is a file or directory

# %%
import os

def checkIfPathOrDirectory(path):
    if os.path.isfile(path):
        print(f"The path {path} is a file")
    elif os.path.isdir(path):
        print(f"The path {path} is a directory")
    else:
        print(f"The path {path} is neither a file nor a directory")

checkIfPathOrDirectory(path2)
checkIfPathOrDirectory(path3)
checkIfPathOrDirectory(path)
# Out:
# The path package is a directory
# The path filePath.ipynb is a file
# The path example1.txt is neither a file nor a directory

# %% [markdown]
# Absolute Path

# %%
relativePath="filePath.ipynb"
absolutePath=os.path.abspath(relativePath)
print(absolutePath)
# Out:
# c:\Users\jaimi\Documents\Programacao\Data_analyst_bootcamp_from_basics_to_advanced\S3_Complete_Python\9_file_path\filePath.ipynb
