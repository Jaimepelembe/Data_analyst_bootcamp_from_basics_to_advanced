# %%
###Line Continuation

total= 1+2+3+4\
+5+6+7+8
print(total)
# Out:
# 36

# %%
##Multiple Statments on a single line
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %% [markdown]
# Undersatanding Semantics

# %%
## Variable assignment
age=22
name="Jaime"
isTrue=False

##Type Inference
#Python is a dinamic language
def  printTypeOf(data):
    print(type(data))

printTypeOf(age)    
printTypeOf(name)    
printTypeOf(isTrue)    

print("***Dinamic attribuition of types***")
variable=2025
printTypeOf(variable)
variable=True
printTypeOf(variable)
variable="James"
printTypeOf(variable)
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>
# ***Dinamic attribuition of types***
# <class 'int'>
# <class 'bool'>
# <class 'str'>

# %% [markdown]
# Comments

# %%
#Single Line comment (#)
#Hello world


'''
Multiple line comment
'''

# %% [markdown]
# Errors

# %%
#Name Error
a=b

# %%
#Code example of indentation
if True:
    print("Correct Indentation")
    if False:
        print("This ont print")
    print("This will print")
print("Outside the if block")
# Out:
# Correct Indentation
# This will print
# Outside the if block
