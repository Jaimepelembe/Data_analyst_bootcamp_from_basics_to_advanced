# %% [markdown]
# ####Basic data types
# Integers
# Foating-point numbers
# Strings
# Booleans

# %%
#Integers
days=7
type(days)
# Out:
# int

# %%
#Float
height=1.78
type(height)
# Out:
# float

# %%
#String
name="Thanos"
type(name)
# Out:
# str

# %%
#Boolean
isValid=True
type(isValid)
var= bool()
var
# Out:
# True

# %% [markdown]
# ###Advanced data types
# Lists
# Tuples
# Sets
# Dictionaries
