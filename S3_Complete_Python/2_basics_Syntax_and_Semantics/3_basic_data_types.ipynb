# %% [markdown]
# ####Basic data types
# Integers
# Foating-point numbers
# Strings
# Booleans

# %%
#Integers
days=7
type(days)
# Out:
# int

# %%
#Float
height=1.78
type(height)
# Out:
# float

# %%
#String
name="Thanos"
type(name)
# Out:
# str

# %%
#Boolean
isValid=True
type(isValid)
var= bool()
var
# Out:
# False

# %% [markdown]
# Common errors

# %%
#Concationate different types of data
result="1"+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 #Concationate diferent types of data
# ----> 2 result="1"+1
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ###Advanced data types
# Lists
# Tuples
# Sets
# Dictionaries
