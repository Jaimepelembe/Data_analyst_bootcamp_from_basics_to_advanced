# %% [markdown]
# Loops in Python
#
# 1. For loop
# - Iterating over a range
# - Iterating over a string
#
# 2. While loop
#
# 3. Loop control statements
# -Break
# -Continue
# 4. Nested loops

# %%
# 1. For loop
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1,6) :
    print(i)


#Decrescent order
print("===========================")
for i in range(10,1,-1):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# ...
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
#Interating Strings
string="Manchester City"

for i in string:
    print(i)
# Out:
# M
# a
# n
# c
# h
# e
# s
# t
# e
# r
#
# C
# i
# t
# y

# %%
#2.While loop

count=0

while count<5:
    print(count)
    count=count+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#3. Loop control statements

#3.1 Break
# The loop ends immediately and the program jump to the next instruction before the loop

for i in range (1,6):
    if i%4==0 and i<5:
        break
    print(i)
# Out:
# 1
# 2
# 3

# %%
#3.2 Continue
# Skips the current iteration and continues with the next iteration.

for i in range(15):
    if i%2==0:
        continue #Skips the odd numbers
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9
# 11
# 13

# %%
#3.3 Pass
# Is a null operation. It does nothing
#It works as a placeholder to keep a valid structure of code

if True:
    pass # without pass, Python would give an error, because it needs a block of code.

for i in range(5):
    pass 


for i in range(7):
    if i==3:
        pass
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
#4. Nested loops
# A loop inside anoter loop

for i in range(3):
    for j in range(2):
        for k in range (2): 
            print (f"i: {i} and j: {j} and k: {k}")
# Out:
# i: 0 and j: 0 and k: 0
# i: 0 and j: 0 and k: 1
# i: 0 and j: 1 and k: 0
# i: 0 and j: 1 and k: 1
# i: 1 and j: 0 and k: 0
# i: 1 and j: 0 and k: 1
# i: 1 and j: 1 and k: 0
# i: 1 and j: 1 and k: 1
# i: 2 and j: 0 and k: 0
# i: 2 and j: 0 and k: 1
# i: 2 and j: 1 and k: 0
# i: 2 and j: 1 and k: 1

# %%
#Examples

#1. Calculate the sum of first N natural numbers using a while and for loop

inputString=input("How many first natural numbers do you want to sum?: ")
if inputString.isnumeric:
    naturalNumber=int(inputString)
    count=0
    sum=0
    while count<=naturalNumber:
        sum=sum+count
        count=count+1

    print(f"The sum of the firts {naturalNumber} natural number is: {sum}")
# Out:
# The sum of the firts 10 natural number is: 55

# %%
#Using for loop:
inputString=input("How many first natural numbers do you want to sum?: ")
if inputString.isnumeric:
    naturalNumber=int(inputString)
    sum=0
    for i in range(naturalNumber+1):
        sum=sum+i
    
    print(f"The sum of the firts {naturalNumber} natural number is: {sum}")
# Out:
# The sum of the firts 5 natural number is: 15

# %%
#Print the prime numbers between 1 and 100

count=0
number=1
divisores=2
while count<100:
    while divisores==2:
        pass

# %%
#Using for loop
limiteSuperior=20
isPrime=True
print("The prime numbers are: ")
for i in range(2,limiteSuperior+1):
    for j in range (2,i): 
        if i%j==0:  # A prime number is only divided by one and it self. If it find another number it is not a prime number 
            isPrime=False
            break
        
    if isPrime: 
        print(i)
    else:
        isPrime=True
# Out:
# 2 is prime
# 3 is prime
# 5 is prime
# 7 is prime
# 11 is prime
# 13 is prime
# 17 is prime
# 19 is prime

# %%
print(5%4)
# Out:
# 2
