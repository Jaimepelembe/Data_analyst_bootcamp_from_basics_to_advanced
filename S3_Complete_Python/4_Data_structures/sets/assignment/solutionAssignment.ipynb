# %% [markdown]
# Assignment 3: Set Operations
# Create two sets: one with the first 5 positive integers and another with the first 5 even integers. Perform and print the results of union, intersection, difference, and symmetric difference operations on these sets.

# %%
setPositiveIntegers={0,1,2,3,4}
setEvenIntegers={1,3,5,7}
print("Union: ",setPositiveIntegers.union(setEvenIntegers))
print("Intersection: ",setPositiveIntegers.intersection(setEvenIntegers))
print("difference : ",setPositiveIntegers.difference(setEvenIntegers))
print("Symmetric difference: ",setPositiveIntegers.symmetric_difference(setEvenIntegers))
# Out:
# Union:  {0, 1, 2, 3, 4, 5, 7}
# Intersection:  {1, 3}
# difference :  {0, 2, 4}
# Symmetric difference:  {0, 2, 4, 5, 7}

# %% [markdown]
# Assignment 4: Set Comprehensions
# Create a new set containing the squares of the first 10 positive

# %%
setComprehension={i**2 for i in range(10)}
print(setComprehension)
# Out:
# {0, 1, 64, 4, 36, 9, 16, 49, 81, 25}

# %% [markdown]
# Assignment 5: Filtering Sets
# Create a new set containing only the even numbers from the set created in Assignment 1 using a set comprehension. Print the new set.

# %%
setEvenNumbers={i for i in range(10) if i%2 != 0}
print(setEvenNumbers)
# Out:
# {1, 3, 5, 7, 9}

# %% [markdown]
# Assignment 7: Subsets and Supersets
# Create two sets: one with the first 5 positive integers and another with the first 3 positive integers. Check if the second set is a subset of the first set and if the first set is a superset of the second set. Print the results.

# %%
setFivePositive={0,1,2,3,4}
setThreePositive={0,1,2}
print(setThreePositive.issubset(setFivePositive))
print(setFivePositive.issuperset(setFivePositive))
# Out:
# True
# True

# %% [markdown]
# Assignment 8: Frozenset
# Create a frozenset with the first 5 positive integers. Print the frozenset.

# %%
setImutavel=frozenset(range(5))
print(setImutavel)
# Out:
# frozenset({0, 1, 2, 3, 4})

# %% [markdown]
# Assignment 10: Set and Dictionary
# Create a dictionary with set keys and integer values. Print the dictionary.

# %%
dictionary={frozenset({0,0}):0,frozenset({0,1}):1,frozenset({1,0}):2, frozenset({1,1}):3} #The original set is unhashable, because that we use the frozenset
print(dictionary)
# Out:
# {frozenset({0}): 0, frozenset({0, 1}): 2, frozenset({1}): 3}
